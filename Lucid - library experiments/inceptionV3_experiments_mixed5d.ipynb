# %%
import numpy as np
import tensorflow as tf
import lucid.modelzoo.vision_models as models
from lucid.misc.io import show
import lucid.optvis.objectives as objectives
import lucid.optvis.param as param
import lucid.optvis.render as render
import lucid.optvis.transform as transform
# Out:
# C:\anaconda3\lib\site-packages\h5py\__init__.py:34: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %%
v3=models.inceptionV3()
v3.load_graphdef()

# %%
l2=lambda layer: objectives.L2(layer=layer)
l1=lambda layer: objectives.L1(layer=layer)
sp=lambda layer,w: objectives.sigmoid_prob(layer=layer,w=w)
tv=lambda layer: objectives.total_variation(layer=layer)
dd=lambda layer: objectives.deepdream(layer=layer)
lg=lambda layer,l: objectives.class_logit(layer=layer,label=l)
channel=lambda layer,n: objectives.channel(layer=layer,n_channel=n)
channel_sig=lambda layer,n: objectives.channel_sigmoid(layer=layer,n_channel=n)
channel_sig_neg=lambda layer,n: objectives.channel_sigmoid(layer=layer,n_channel=n)

# %%
obj=channel('InceptionV3/InceptionV3/Mixed_5d/concat_v2',0)
_=render.render_vis(model=v3,objective_f=obj,thresholds=(1024,))
# Out:
# 1024 5.2153754
# <img src="data:image/PNG;base64,...">

# %%
obj=channel_sig('InceptionV3/InceptionV3/Mixed_5d/concat_v2',0)
_=render.render_vis(model=v3,objective_f=obj,thresholds=(1024,))
# Out:
# 1024 6.056867
# <img src="data:image/PNG;base64,...">

# %%
obj=channel_sig_neg('InceptionV3/InceptionV3/Mixed_5d/concat_v2',0)
_=render.render_vis(model=v3,objective_f=obj,thresholds=(1024,))
# Out:
# 1024 4.638837
# <img src="data:image/PNG;base64,...">

# %%
obj=channel('InceptionV3/InceptionV3/Mixed_5d/concat_v2',1)
_=render.render_vis(model=v3,objective_f=obj,thresholds=(1024,))
# Out:
# 1024 4.870454
# <img src="data:image/PNG;base64,...">

# %%
obj=channel_sig('InceptionV3/InceptionV3/Mixed_5d/concat_v2',1)
_=render.render_vis(model=v3,objective_f=obj,thresholds=(1024,))
# Out:
# 1024 5.3419213
# <img src="data:image/PNG;base64,...">

# %%
obj=channel_sig_neg('InceptionV3/InceptionV3/Mixed_5d/concat_v2',1)
_=render.render_vis(model=v3,objective_f=obj,thresholds=(1024,))
# Out:
# 1024 5.0379896
# <img src="data:image/PNG;base64,...">

# %%
obj=channel('InceptionV3/InceptionV3/Mixed_5d/concat_v2',2)
_=render.render_vis(model=v3,objective_f=obj,thresholds=(1024,))
# Out:
# 1024 3.0896826
# <img src="data:image/PNG;base64,...">

# %%
obj=channel_sig('InceptionV3/InceptionV3/Mixed_5d/concat_v2',2)
_=render.render_vis(model=v3,objective_f=obj,thresholds=(1024,))
# Out:
# 1024 2.945987
# <img src="data:image/PNG;base64,...">

# %%
obj=channel_sig_neg('InceptionV3/InceptionV3/Mixed_5d/concat_v2',2)
_=render.render_vis(model=v3,objective_f=obj,thresholds=(1024,))
# Out:
# 1024 3.0579314
# <img src="data:image/PNG;base64,...">

# %%
obj=channel('InceptionV3/InceptionV3/Mixed_5d/concat_v2',3)
_=render.render_vis(model=v3,objective_f=obj,thresholds=(1024,))
# Out:
# 1024 3.736475
# <img src="data:image/PNG;base64,...">

# %%
obj=channel_sig('InceptionV3/InceptionV3/Mixed_5d/concat_v2',3)
_=render.render_vis(model=v3,objective_f=obj,thresholds=(1024,))
# Out:
# 1024 4.0047708
# <img src="data:image/PNG;base64,...">

# %%
obj=channel_sig_neg('InceptionV3/InceptionV3/Mixed_5d/concat_v2',3)
_=render.render_vis(model=v3,objective_f=obj,thresholds=(1024,))
# Out:
# 1024 4.477818
# <img src="data:image/PNG;base64,...">
